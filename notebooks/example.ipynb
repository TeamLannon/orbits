# %%
from orbits.test import test

# %%
test()
# Out:
# This is a test.

# %%
from orbits.test import add
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from orbits.test import add
#
# ImportError: cannot import name 'add' from 'orbits.test' (/Users/gwynethlannon/python/orbits/src/orbits/test.py)
