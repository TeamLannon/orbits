# %%
from astroquery.jplhorizons import Horizons
from astropy.time import Time

# %%
obj = Horizons(id='3', location="@0", epochs={'start':"2022-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
obj
# Out:
# <Table masked=True length=366>
#         targetname        datetime_jd ...       range_rate
#            ---                 d      ...         AU / d
#           str25             float64   ...        float64
# ------------------------- ----------- ... ---------------------
# Earth-Moon Barycenter (3)   2459580.5 ... 0.0001167860574970616
# Earth-Moon Barycenter (3)   2459581.5 ... 0.0001204925025201987
# Earth-Moon Barycenter (3)   2459582.5 ... 0.0001241641881875982
# Earth-Moon Barycenter (3)   2459583.5 ...  0.000127799962962254
# Earth-Moon Barycenter (3)   2459584.5 ... 0.0001313986907208048
#                       ...         ... ...                   ...
# Earth-Moon Barycenter (3)   2459941.5 ... 0.0001145390943589622
# Earth-Moon Barycenter (3)   2459942.5 ... 0.0001192323715815197
# Earth-Moon Barycenter (3)   2459943.5 ... 0.0001238918276433263
# Earth-Moon Barycenter (3)   2459944.5 ...  0.000128515951098346
# ...

# %%
x = obj['x'].value

# %%
y = obj['y'].value

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(x, y)
plt.ylabel('y (AU)')
plt.xlabel('x (AU)')
plt.title('Distance between Earth-Moon Barycenter and Solar System Barycenter during 2022')
# Out:
# Text(0.5, 1.0, 'Distance between Earth-Moon Barycenter and Solar System Barycenter during 2022')

# %%
obj = Horizons(id='3', location="@0", epochs={'start':"1923-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
obj
# Out:
# <Table masked=True length=36526>
#         targetname        datetime_jd ...       range_rate
#            ---                 d      ...         AU / d
#           str25             float64   ...        float64
# ------------------------- ----------- ... ----------------------
# Earth-Moon Barycenter (3)   2423420.5 ... -0.0001372240581233387
# Earth-Moon Barycenter (3)   2423421.5 ...  -0.000132492461283621
# Earth-Moon Barycenter (3)   2423422.5 ... -0.0001277219778033079
# Earth-Moon Barycenter (3)   2423423.5 ... -0.0001229141613109988
# Earth-Moon Barycenter (3)   2423424.5 ... -0.0001180705792972285
#                       ...         ... ...                    ...
# Earth-Moon Barycenter (3)   2459941.5 ...  0.0001145390943589622
# Earth-Moon Barycenter (3)   2459942.5 ...  0.0001192323715815197
# Earth-Moon Barycenter (3)   2459943.5 ...  0.0001238918276433263
# Earth-Moon Barycenter (3)   2459944.5 ...   0.000128515951098346
# ...

# %%
x = obj['x'].value
y = obj['y'].value
fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(x, y)
plt.ylabel('y (AU)')
plt.xlabel('x (AU)')
plt.title('Distance between Earth-Moon Barycenter and Solar System Barycenter 1923-2022')
# Out:
# Text(0.5, 1.0, 'Distance between Earth-Moon Barycenter and Solar System Barycenter 1923-2022')

# %%
obj = Horizons(id='3', location="@0", epochs={'start':"2022-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
obj
# Out:
# <Table masked=True length=366>
#         targetname        datetime_jd ...       range_rate
#            ---                 d      ...         AU / d
#           str25             float64   ...        float64
# ------------------------- ----------- ... ---------------------
# Earth-Moon Barycenter (3)   2459580.5 ... 0.0001167860574970616
# Earth-Moon Barycenter (3)   2459581.5 ... 0.0001204925025201987
# Earth-Moon Barycenter (3)   2459582.5 ... 0.0001241641881875982
# Earth-Moon Barycenter (3)   2459583.5 ...  0.000127799962962254
# Earth-Moon Barycenter (3)   2459584.5 ... 0.0001313986907208048
#                       ...         ... ...                   ...
# Earth-Moon Barycenter (3)   2459941.5 ... 0.0001145390943589622
# Earth-Moon Barycenter (3)   2459942.5 ... 0.0001192323715815197
# Earth-Moon Barycenter (3)   2459943.5 ... 0.0001238918276433263
# Earth-Moon Barycenter (3)   2459944.5 ...  0.000128515951098346
# ...

# %%
x = obj['x'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, x)
plt.ylabel('x (AU)')
plt.xlabel('t (d)')
plt.title('X-Coordinate of Earth-Moon Barycenter in 2022')
# Out:
# Text(0.5, 1.0, 'X-Coordinate of Earth-Moon Barycenter in 2022')

# %%
obj = Horizons(id='3', location="@0", epochs={'start':"1923-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
x = obj['x'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, x)
plt.ylabel('x (AU)')
plt.xlabel('t (d)')
plt.title('X-Coordinate of Earth-Moon Barycenter 1923-2022')
# Out:
# Text(0.5, 1.0, 'X-Coordinate of Earth-Moon Barycenter 1923-2022')

# %%
obj = Horizons(id='3', location="@0", epochs={'start':"2022-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
y = obj['y'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, y)
plt.ylabel('y (AU)')
plt.xlabel('t (d)')
plt.title('Y-Coordinate of Earth-Moon Barycenter in 2022')
# Out:
# Text(0.5, 1.0, 'Y-Coordinate of Earth-Moon Barycenter in 2022')

# %%
obj = Horizons(id='3', location="@0", epochs={'start':"1923-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
y = obj['y'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, y)
plt.ylabel('y (AU)')
plt.xlabel('t (d)')
plt.title('Y-Coordinate of Earth-Moon Barycenter 1923-2022')
# Out:
# Text(0.5, 1.0, 'Y-Coordinate of Earth-Moon Barycenter 1923-2022')

# %%
obj = Horizons(id='3', location="@0", epochs={'start':"2022-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
z = obj['z'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, z)
plt.ylabel('z (AU)')
plt.xlabel('t (d)')
plt.title('Z-Coordinate of Earth-Moon Barycenter in 2022')
# Out:
# Text(0.5, 1.0, 'Z-Coordinate of Earth-Moon Barycenter in 2022')

# %%
obj = Horizons(id='3', location="@0", epochs={'start':"1923-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
z = obj['z'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, z)
plt.ylabel('z (AU)')
plt.xlabel('t (d)')
plt.title('Z-Coordinate of Earth-Moon Barycenter 1923-2022')
# Out:
# Text(0.5, 1.0, 'Z-Coordinate of Earth-Moon Barycenter 1923-2022')

# %%
obj = Horizons(id='3', location="@0", epochs={'start':"2022-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
vx = obj['vx'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, vx)
plt.ylabel('vx (AU/d)')
plt.xlabel('t (d)')
plt.title('X-Velocity of Earth-Moon Barycenter in 2022')
# Out:
# Text(0.5, 1.0, 'X-Velocity of Earth-Moon Barycenter in 2022')

# %%
obj = Horizons(id='3', location="@0", epochs={'start':"1923-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
vx = obj['vx'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, vx)
plt.ylabel('vx (AU/d)')
plt.xlabel('t (d)')
plt.title('X-Velocity of Earth-Moon Barycenter 1923-2022')
# Out:
# Text(0.5, 1.0, 'X-Velocity of Earth-Moon Barycenter 1923-2022')

# %%
obj = Horizons(id='3', location="@0", epochs={'start':"2022-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
vy = obj['vy'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, vy)
plt.ylabel('vy (AU/d)')
plt.xlabel('t (d)')
plt.title('Y-Velocity of Earth-Moon Barycenter in 2022')
# Out:
# Text(0.5, 1.0, 'Y-Velocity of Earth-Moon Barycenter in 2022')

# %%
obj = Horizons(id='3', location="@0", epochs={'start':"1923-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
vy = obj['vy'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, vy)
plt.ylabel('vy (AU/d)')
plt.xlabel('t (d)')
plt.title('Y-Velocity of Earth-Moon Barycenter 1923-2022')
# Out:
# Text(0.5, 1.0, 'Y-Velocity of Earth-Moon Barycenter 1923-2022')

# %%
obj = Horizons(id='3', location="@0", epochs={'start':"2022-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
vz = obj['vz'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, vz)
plt.ylabel('vz (AU/d)')
plt.xlabel('t (d)')
plt.title('Z-Velocity of Earth-Moon Barycenter in 2022')
# Out:
# Text(0.5, 1.0, 'Z-Velocity of Earth-Moon Barycenter in 2022')

# %%
obj = Horizons(id='3', location="@0", epochs={'start':"1923-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
vz = obj['vz'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, vz)
plt.ylabel('vz (AU/d)')
plt.xlabel('t (d)')
plt.title('Z-Velocity of Earth-Moon Barycenter 1923-2022')
# Out:
# Text(0.5, 1.0, 'Z-Velocity of Earth-Moon Barycenter 1923-2022')

# %%
obj = Horizons(id='301', location="@0", epochs={'start':"2022-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
x = obj['x'].value
y = obj['y'].value
fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(x, y)
plt.ylabel('x (AU)')
plt.xlabel('y (AU)')
plt.title('Position of Moon in 2022')
# Out:
# Text(0.5, 1.0, 'Position of Moon in 2022')

# %%
obj = Horizons(id='301', location="@0", epochs={'start':"2022-01-01",'stop':"2022-01-08",'step':'1h'}, id_type=None).vectors()
x = obj['x'].value
y = obj['y'].value
fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(x, y)
plt.ylabel('x (AU)')
plt.xlabel('y (AU)')
plt.title('Position of Moon in January 2022')
# Out:
# Text(0.5, 1.0, 'Position of Moon in January 2022')

# %%
obj = Horizons(id='301', location="@0", epochs={'start':"2022-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
x = obj['x'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, x)
plt.ylabel('x (AU)')
plt.xlabel('t (d)')
plt.title('X-Coordinate of Moon in 2022')
# Out:
# Text(0.5, 1.0, 'X-Coordinate of Moon in 2022')

# %%
obj = Horizons(id='301', location="@0", epochs={'start':"1923-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
x = obj['x'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, x)
plt.ylabel('x (AU)')
plt.xlabel('t (d)')
plt.title('X-Coordinate of Moon 1923-2022')
# Out:
# Text(0.5, 1.0, 'X-Coordinate of Moon 1923-2022')

# %%
obj = Horizons(id='301', location="@0", epochs={'start':"2022-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
y = obj['y'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, y)
plt.ylabel('y (AU)')
plt.xlabel('t (d)')
plt.title('Y-Coordinate of Moon in 2022')
# Out:
# Text(0.5, 1.0, 'Y-Coordinate of Moon in 2022')

# %%
obj = Horizons(id='301', location="@0", epochs={'start':"2022-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
z = obj['z'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, z)
plt.ylabel('z (AU)')
plt.xlabel('t (d)')
plt.title('Z-Coordinate of Moon in 2022')
# Out:
# Text(0.5, 1.0, 'Z-Coordinate of Moon in 2022')

# %%
obj = Horizons(id='301', location="@0", epochs={'start':"1923-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
z = obj['z'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, z)
plt.ylabel('z (AU)')
plt.xlabel('t (d)')
plt.title('Z-Coordinate of Moon 1923-2022')
# Out:
# Text(0.5, 1.0, 'Z-Coordinate of Moon 1923-2022')

# %%
obj = Horizons(id='301', location="@0", epochs={'start':"2022-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
vx = obj['vx'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, vx)
plt.ylabel('vx (AU/d)')
plt.xlabel('t (d)')
plt.title('X-Component of Moon Velocity in 2022')
# Out:
# Text(0.5, 1.0, 'X-Component of Moon Velocity in 2022')

# %%
obj = Horizons(id='301', location="@0", epochs={'start':"1923-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
vx = obj['vx'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, vx)
plt.ylabel('vx (AU/d)')
plt.xlabel('t (d)')
plt.title('X-Component of Moon Velocity 1923-2022')
# Out:
# Text(0.5, 1.0, 'X-Component of Moon Velocity 1923-2022')

# %%
obj = Horizons(id='301', location="@0", epochs={'start':"2022-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
vy = obj['vy'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, vy)
plt.ylabel('vy (AU/d)')
plt.xlabel('t (d)')
plt.title('Y-Component of Moon Velocity in 2022')
# Out:
# Text(0.5, 1.0, 'Y-Component of Moon Velocity in 2022')

# %%
obj = Horizons(id='301', location="@0", epochs={'start':"2022-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
vz = obj['vz'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, vz)
plt.ylabel('vz (AU/d)')
plt.xlabel('t (d)')
plt.title('Z-Component of Moon Velocity in 2022')
# Out:
# Text(0.5, 1.0, 'Z-Component of Moon Velocity in 2022')

# %%
obj = Horizons(id='301', location="@0", epochs={'start':"1923-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
vz = obj['vz'].value
t = obj['datetime_jd'].value - obj['datetime_jd'].value[0]
plt.plot(t, vz)
plt.ylabel('vz (AU/d)')
plt.xlabel('t (d)')
plt.title('Z-Component of Moon Velocity 1923-2022')
# Out:
# Text(0.5, 1.0, 'Z-Component of Moon Velocity 1923-2022')

# %%
mercury = Horizons(id='1', location="@0", epochs={'start':"2022-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
mercury
# Out:
# <Table masked=True length=366>
#        targetname        datetime_jd ...       range_rate
#           ---                 d      ...         AU / d
#          str24             float64   ...        float64
# ------------------------ ----------- ... ----------------------
# Mercury Barycenter (199)   2459580.5 ...   -0.00559416313978368
# Mercury Barycenter (199)   2459581.5 ...   -0.00546358891385341
# Mercury Barycenter (199)   2459582.5 ...  -0.005287648103563136
# Mercury Barycenter (199)   2459583.5 ...  -0.005063732792211667
# Mercury Barycenter (199)   2459584.5 ...   -0.00478976093541203
#                      ...         ... ...                    ...
# Mercury Barycenter (199)   2459941.5 ...  -0.002801760090158842
# Mercury Barycenter (199)   2459942.5 ...  -0.002211275743689576
# Mercury Barycenter (199)   2459943.5 ...  -0.001585112875395046
# Mercury Barycenter (199)   2459944.5 ... -0.0009323760816136147
# ...

# %%
x1 = mercury['x'].value
y1 = mercury['y'].value

# %%
venus = Horizons(id='2', location="@0", epochs={'start':"2022-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
venus
# Out:
# <Table masked=True length=366>
#       targetname       datetime_jd ...       range_rate
#          ---                d      ...         AU / d
#         str22            float64   ...        float64
# ---------------------- ----------- ... ----------------------
# Venus Barycenter (299)   2459580.5 ...  0.0001420124976457577
# Venus Barycenter (299)   2459581.5 ...  0.0001420187825491557
# Venus Barycenter (299)   2459582.5 ...  0.0001419234432151311
# Venus Barycenter (299)   2459583.5 ...  0.0001417263373232393
# Venus Barycenter (299)   2459584.5 ...  0.0001414273971808944
#                    ...         ... ...                    ...
# Venus Barycenter (299)   2459941.5 ...  -0.000178001160520229
# Venus Barycenter (299)   2459942.5 ... -0.0001771359995905543
# Venus Barycenter (299)   2459943.5 ...  -0.000176143823218721
# Venus Barycenter (299)   2459944.5 ... -0.0001750249778310637
# Venus Barycenter (299)   2459945.5 ... -0.0001737798974058923

# %%
x2 = venus['x'].value
y2 = venus['y'].value

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(x1, y1, label="Mercury")
ax.plot(x2, y2, label="Venus")
ax.legend()

# %%
earth = Horizons(id='3', location="@0", epochs={'start':"2022-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
earth
# Out:
# <Table masked=True length=366>
#         targetname        datetime_jd ...       range_rate
#            ---                 d      ...         AU / d
#           str25             float64   ...        float64
# ------------------------- ----------- ... ---------------------
# Earth-Moon Barycenter (3)   2459580.5 ... 0.0001167860574970616
# Earth-Moon Barycenter (3)   2459581.5 ... 0.0001204925025201987
# Earth-Moon Barycenter (3)   2459582.5 ... 0.0001241641881875982
# Earth-Moon Barycenter (3)   2459583.5 ...  0.000127799962962254
# Earth-Moon Barycenter (3)   2459584.5 ... 0.0001313986907208048
#                       ...         ... ...                   ...
# Earth-Moon Barycenter (3)   2459941.5 ... 0.0001145390943589622
# Earth-Moon Barycenter (3)   2459942.5 ... 0.0001192323715815197
# Earth-Moon Barycenter (3)   2459943.5 ... 0.0001238918276433263
# Earth-Moon Barycenter (3)   2459944.5 ...  0.000128515951098346
# ...

# %%
x3 = earth['x'].value
y3 = earth['y'].value

# %%
mars = Horizons(id='4', location="@0", epochs={'start':"2021-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
mars
# Out:
# <Table masked=True length=731>
#      targetname     datetime_jd ...       range            range_rate
#         ---              d      ...         AU               AU / d
#        str19          float64   ...      float64            float64
# ------------------- ----------- ... ----------------- --------------------
# Mars Barycenter (4)   2459215.5 ... 1.512114757771189 0.001377297745886692
# Mars Barycenter (4)   2459216.5 ... 1.513491925284641  0.00137701799247909
# Mars Barycenter (4)   2459217.5 ... 1.514868755288077 0.001376622835048022
# Mars Barycenter (4)   2459218.5 ...  1.51624513270601 0.001376112931624922
# Mars Barycenter (4)   2459219.5 ... 1.517620943123824 0.001375488945871384
#                 ...         ... ...               ...                  ...
# Mars Barycenter (4)   2459941.5 ...  1.55885062917684 0.001301412841112168
# Mars Barycenter (4)   2459942.5 ... 1.560150053325039 0.001297420408577669
# ...

# %%
x4 = mars['x'].value
y4 = mars['y'].value

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(x1, y1, label="Mercury")
ax.plot(x2, y2, label="Venus")
ax.plot(x3, y3, label="Earth")
ax.plot(x4, y4, label="Mars")
ax.legend()
plt.ylabel('x (AU)')
plt.xlabel('y (AU)')
plt.title('Inner Planets')
# Out:
# Text(0.5, 1.0, 'Inner Planets')

# %%
jupiter = Horizons(id='5', location="@0", epochs={'start':"2011-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
jupiter
# Out:
# <Table masked=True length=4384>
#       targetname       datetime_jd ...       range             range_rate
#          ---                d      ...         AU                AU / d
#         str22            float64   ...      float64             float64
# ---------------------- ----------- ... ----------------- ----------------------
# Jupiter Barycenter (5)   2455562.5 ... 4.946039999361187 -4.281241125300672e-05
# Jupiter Barycenter (5)   2455563.5 ... 4.945997481201487   -4.2223888264606e-05
# Jupiter Barycenter (5)   2455564.5 ... 4.945955551624147 -4.163524680907675e-05
# Jupiter Barycenter (5)   2455565.5 ... 4.945914210746808  -4.10464885357825e-05
# Jupiter Barycenter (5)   2455566.5 ... 4.945873458685463 -4.045761509434733e-05
#                    ...         ... ...               ...                    ...
# Jupiter Barycenter (5)   2459941.5 ... 4.942329811337169 -1.148871422312863e-05
# Jupiter Barycenter (5)   2459942.5 ... 4.942318617437446 -1.089908037382942e-05
# ...

# %%
x5 = jupiter['x'].value
y5 = jupiter['y'].value

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(x1, y1, label="Mercury")
ax.plot(x2, y2, label="Venus")
ax.plot(x3, y3, label="Earth")
ax.plot(x4, y4, label="Mars")
ax.plot(x5, y5, label="Jupiter")
ax.legend()
plt.ylabel('x (AU)')
plt.xlabel('y (AU)')
plt.title('Inner Planets and Jupiter')
# Out:
# Text(0.5, 1.0, 'Inner Planets and Jupiter')

# %%
saturn = Horizons(id='6', location="@0", epochs={'start':"1993-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
saturn
# Out:
# <Table masked=True length=10958>
#       targetname      datetime_jd ...       range             range_rate
#          ---               d      ...         AU                AU / d
#         str21           float64   ...      float64             float64
# --------------------- ----------- ... ----------------- ----------------------
# Saturn Barycenter (6)   2448988.5 ... 9.863309681847912 -0.0002193820740366416
# Saturn Barycenter (6)   2448989.5 ... 9.863090245024363 -0.0002194915626432002
# Saturn Barycenter (6)   2448990.5 ... 9.862870698743473 -0.0002196009887113901
# Saturn Barycenter (6)   2448991.5 ... 9.862651043067801  -0.000219710352200852
# Saturn Barycenter (6)   2448992.5 ... 9.862431278059946  -0.000219819653071215
#                   ...         ... ...               ...                    ...
# Saturn Barycenter (6)   2459941.5 ... 9.829008024159522 -0.0002477044987730332
# Saturn Barycenter (6)   2459942.5 ... 9.828760270557492 -0.0002478026926241618
# ...

# %%
x6 = saturn['x'].value
y6 = saturn['y'].value

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(x1, y1, label="Mercury")
ax.plot(x2, y2, label="Venus")
ax.plot(x3, y3, label="Earth")
ax.plot(x4, y4, label="Mars")
ax.plot(x5, y5, label="Jupiter")
ax.plot(x6, y6, label="Saturn")
ax.legend()
plt.ylabel('x (AU)')
plt.xlabel('y (AU)')
plt.title('Adding Saturn')
# Out:
# Text(0.5, 1.0, 'Adding Saturn')

# %%
uranus = Horizons(id='7', location="@0", epochs={'start':"1938-12-25",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
uranus
# Out:
# <Table masked=True length=30689>
#       targetname      datetime_jd ...       range             range_rate
#          ---               d      ...         AU                AU / d
#         str21           float64   ...      float64             float64
# --------------------- ----------- ... ----------------- ----------------------
# Uranus Barycenter (7)   2429257.5 ... 19.66355671913768 -0.0001544122530035382
# Uranus Barycenter (7)   2429258.5 ... 19.66340229687165 -0.0001544322782018592
# Uranus Barycenter (7)   2429259.5 ... 19.66324785458297 -0.0001544522983244735
# Uranus Barycenter (7)   2429260.5 ... 19.66309339227669 -0.0001544723133715889
# Uranus Barycenter (7)   2429261.5 ... 19.66293890995792 -0.0001544923233434185
#                   ...         ... ...               ...                    ...
# Uranus Barycenter (7)   2459941.5 ... 19.66442186158497 -0.0001542458794304689
# Uranus Barycenter (7)   2459942.5 ... 19.66426760564828 -0.0001542659931060701
# ...

# %%
x7 = uranus['x'].value
y7 = uranus['y'].value

# %%
fig, ax = plt.subplots(figsize=(9, 9))
ax.plot(x1, y1, label="Mercury")
ax.plot(x2, y2, label="Venus")
ax.plot(x3, y3, label="Earth")
ax.plot(x4, y4, label="Mars")
ax.plot(x5, y5, label="Jupiter")
ax.plot(x6, y6, label="Saturn")
ax.plot(x7, y7, label="Uranus")
ax.legend()
plt.ylabel('x (AU)')
plt.xlabel('y (AU)')
plt.title('Plus Uranus')
# Out:
# Text(0.5, 1.0, 'Plus Uranus')

# %%
neptune = Horizons(id='8', location="@0", epochs={'start':"1858-01-01",'stop':"2023-01-01",'step':'1d'}, id_type=None).vectors()
neptune
# Out:
# <Table masked=True length=60266>
#       targetname       datetime_jd ...       range             range_rate
#          ---                d      ...         AU                AU / d
#         str22            float64   ...      float64             float64
# ---------------------- ----------- ... ----------------- ----------------------
# Neptune Barycenter (8)   2399680.5 ... 29.90813996770028 -2.107349373340931e-05
# Neptune Barycenter (8)   2399681.5 ... 29.90811889511004 -2.107168669174344e-05
# Neptune Barycenter (8)   2399682.5 ... 29.90809782432699 -2.106987936660613e-05
# Neptune Barycenter (8)   2399683.5 ...  29.9080767553514  -2.10680717581619e-05
# Neptune Barycenter (8)   2399684.5 ... 29.90805568818357 -2.106626386657547e-05
#                    ...         ... ...               ...                    ...
# Neptune Barycenter (8)   2459941.5 ... 29.90360140065618 -2.101876538748352e-05
# Neptune Barycenter (8)   2459942.5 ... 29.90358038280111 -2.101694472286846e-05
# ...

# %%
x8 = neptune['x'].value
y8 = neptune['y'].value

# %%
fig, ax = plt.subplots(figsize=(9, 9))
ax.plot(x1, y1, label="Mercury")
ax.plot(x2, y2, label="Venus")
ax.plot(x3, y3, label="Earth")
ax.plot(x4, y4, label="Mars")
ax.plot(x5, y5, label="Jupiter")
ax.plot(x6, y6, label="Saturn")
ax.plot(x7, y7, label="Uranus")
ax.plot(x8, y8, label="Neptune")
ax.legend()
plt.ylabel('x (AU)')
plt.xlabel('y (AU)')
plt.title('Now for Neptune')
# Out:
# Text(0.5, 1.0, 'Now for Neptune')

# %%
pluto = Horizons(id='9', location="@0", epochs={'start':"1775-01-01",'stop':"2023-01-01",'step':'1y'}, id_type=None).vectors()
pluto
# Out:
# <Table masked=True length=249>
#      targetname      datetime_jd ...       range             range_rate
#         ---               d      ...         AU                AU / d
#        str20           float64   ...      float64             float64
# -------------------- ----------- ... ----------------- ---------------------
# Pluto Barycenter (9)   2369365.5 ... 34.63623464298296 0.0006763534002607562
# Pluto Barycenter (9)   2369730.5 ... 34.88419507996642  0.000682206212671605
# Pluto Barycenter (9)   2370096.5 ... 35.13484077690269 0.0006873182673786129
# Pluto Barycenter (9)   2370461.5 ... 35.38653114693198 0.0006916880982284744
# Pluto Barycenter (9)   2370826.5 ... 35.63968788273286 0.0006953575602572509
#                  ...         ... ...               ...                   ...
# Pluto Barycenter (9)   2458484.5 ... 33.70463900445258 0.0006463273078250674
# Pluto Barycenter (9)   2458849.5 ... 33.94221419561833   0.00065531125065583
# ...

# %%
x9 = pluto['x'].value
y9 = pluto['y'].value

# %%
fig, ax = plt.subplots(figsize=(9, 9))
ax.plot(x1, y1, label="Mercury")
ax.plot(x2, y2, label="Venus")
ax.plot(x3, y3, label="Earth")
ax.plot(x4, y4, label="Mars")
ax.plot(x5, y5, label="Jupiter")
ax.plot(x6, y6, label="Saturn")
ax.plot(x7, y7, label="Uranus")
ax.plot(x8, y8, label="Neptune")
ax.plot(x9, y9, label="Pluto")
ax.legend()
plt.ylabel('x (AU)')
plt.xlabel('y (AU)')
plt.title('Full Solar System')
# Out:
# Text(0.5, 1.0, 'Full Solar System')
